# %% [markdown]
# # Reading csv-files

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# ## Path

# %%
# get current path
os.getcwd()
# Out:
# '/home/juliaeis/Dokumente/Python_support_group/notebooks'

# %%
# print all elements from actual path
os.listdir('.')
# Out:
# ['04_ReadCSV.ipynb',
#  'Untitled.ipynb',
#  '.ipynb_checkpoints',
#  '01_NumbersStringLists.ipynb',
#  '03_ControlFlow.ipynb',
#  '02_BooleansTuplesDictionaries.ipynb']

# %%
# print all elements from parent directory
os.listdir('../')
# Out:
# ['data', '.git', '.gitignore', 'README.md', 'notebooks']

# %%
# go to the directory with the data and list all elements
os.listdir('../data/alpsdata')
# Out:
# ['diagdata_oetztal_station.dat',
#  'diagdata_oetztal_station.dat.1',
#  'measurements_oetztal_station.dat.1',
#  'measurements_oetztal_station.dat',
#  'measurements_kaunertal_station.dat',
#  'diagdata_kaunertal_station.dat.1',
#  'measurements_kaunertal_station.dat.1',
#  'diagdata_kaunertal_station.dat']

# %%
# path to csv
p = '../data/Hintereisferner.csv'
df = pd.read_csv(p)

# %%
df
# Out:
#      time  temperature  precipitation   length       area    volume
# 0    1901    -2.764167      1395.8733      NaN        NaN       NaN
# 1    1902    -2.864167      1401.9225      NaN        NaN       NaN
# 2    1903    -2.014167      1589.2112      NaN        NaN       NaN
# 3    1904    -2.655833      1547.7460      NaN        NaN       NaN
# 4    1905    -3.172500      1296.6561      NaN        NaN       NaN
# 5    1906    -3.080834      1347.5193      NaN        NaN       NaN
# 6    1907    -2.680833      1457.0197      NaN        NaN       NaN
# 7    1908    -3.605834      1106.9540      NaN        NaN       NaN
# 8    1909    -2.830833      1743.0535      NaN        NaN       NaN
# 9    1910    -2.222500      1303.4811      NaN        NaN       NaN
# 10   1911    -2.355833      1776.4355      NaN        NaN       NaN
# 11   1912    -3.172500      1440.9896      NaN        NaN       NaN
# 12   1913    -2.455833      1776.4270      NaN        NaN       NaN
# 13   1914    -2.755833      1543.5854      NaN        NaN       NaN
# 14   1915    -2.697500      1639.4452      NaN        NaN       NaN
# 15   1916    -2.664167      1611.8003      NaN        NaN       NaN
# 16   1917    -2.855833      1370.8625  12800.0  13.236071  2.187398
# 17   1918    -2.830833      1511.9441  12800.0  13.199068  2.161535
# 18   1919    -2.172500      1841.1135  12900.0  13.185682  2.152992
# 19   1920    -1.705833      1041.0529  12900.0  13.178835  2.146302
# 20   1921    -2.689166      1456.9905  12900.0  13.170437  2.145655
# 21   1922    -2.730833      1355.4644  12800.0  13.113765  2.106068
# 22   1923    -2.822501      1655.0269  12800.0  13.082572  2.091544
# 23   1924    -2.397500      1149.3410  12800.0  13.063282  2.078114
# 24   1925    -2.380833      1496.1599  12800.0  13.036573  2.069431
# 25   1926    -1.939166      1739.9551  12800.0  13.007703  2.052041
# 26   1927    -1.839167      1342.6393  12700.0  12.991767  2.045050
# 27   1928    -2.997500      1232.9525  12800.0  12.957117  2.029977
# 28   1929    -1.772500      1430.1477  12800.0  12.907000  1.996497
# 29   1930    -2.897500      1520.3717  12700.0  12.837696  1.954838
# ..    ...          ...            ...      ...        ...       ...
# 85   1986    -2.447500      1544.6906   9200.0   9.120569  1.011368
# 86   1987    -1.280833      1522.3516   9100.0   9.052810  0.996791
# 87   1988    -1.322500      1434.7625   8900.0   8.993423  0.983850
# 88   1989    -1.114167      1265.0350   8800.0   8.925775  0.970771
# 89   1990    -1.839167      1253.5315   8700.0   8.860103  0.958218
# 90   1991    -1.405833      1427.6912   8700.0   8.787078  0.941113
# 91   1992    -1.480833      1596.7817   8600.0   8.707654  0.915757
# 92   1993    -1.030833      1537.8982   8500.0   8.631422  0.893901
# 93   1994    -1.505833      1593.6149   8400.0   8.576310  0.884658
# 94   1995    -2.064167      1270.9248   8200.0   8.501101  0.863193
# 95   1996    -1.280833      1504.6875   8300.0   8.462795  0.858251
# 96   1997    -0.905833      1442.6433   8200.0   8.404999  0.844599
# 97   1998    -1.630833      1840.9318   8000.0   8.345531  0.832216
# 98   1999    -1.347500      1563.1625   8100.0   8.279742  0.813355
# 99   2000    -1.139167      1874.1866   8000.0   8.218863  0.800874
# 100  2001    -1.130833      1457.6823   7900.0   8.152411  0.784158
# 101  2002    -0.597500      1199.0962   7700.0   8.108282  0.780570
# 102  2003    -1.689166      1483.4327   7700.0   8.036989  0.759691
# 103  2004    -1.589167      1238.1034      NaN        NaN       NaN
# 104  2005    -1.722500      1299.9250      NaN        NaN       NaN
# 105  2006    -0.022500      1395.4070      NaN        NaN       NaN
# 106  2007    -1.380833      1521.4053      NaN        NaN       NaN
# 107  2008    -1.197500      1462.4127      NaN        NaN       NaN
# 108  2009    -1.897500      1433.7137      NaN        NaN       NaN
# 109  2010    -1.014167      1300.2068      NaN        NaN       NaN
# 110  2011    -0.830833      1574.3645      NaN        NaN       NaN
# 111  2012    -1.530833      1602.6803      NaN        NaN       NaN
# 112  2013    -0.714167      1509.5664      NaN        NaN       NaN
# 113  2014    -0.272500      1447.4198      NaN        NaN       NaN
# 114  2015    -0.405833      1619.9103      NaN        NaN       NaN
#
# [115 rows x 6 columns]

# %%
df.temperature.plot()

# %%
df.temperature.min()
# Out:
# -3.6058337999999996
